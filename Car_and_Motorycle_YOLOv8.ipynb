# %% [markdown]
# <a href="https://colab.research.google.com/github/ImtiazAhammad/Car-and-Motorcycle-YOLOv8/blob/main/Car_and_Motorycle_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 689.8 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.3/716.3 kB 5.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from ultralytics import YOLO
model = YOLO()
model.train(data="/kaggle/input/car-and-motorcycle/car and motorcycle.v1i.yolov8/data.yaml",epochs=50)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 71.4MB/s]
# Ultralytics YOLOv8.1.20 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model = "/kaggle/working/runs/detect/train/weights/best.pt" data ="/kaggle/input/car-and-motorcycle/car and motorcycle.v1i.yolov8/data.yaml"
# Out:
# Ultralytics YOLOv8.1.20 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/input/car-and-motorcycle/car and motorcycle.v1i.yolov8/val
# val: WARNING ⚠️ Cache directory /kaggle/input/car-and-motorcycle/car and motorcycle.v1i.yolov8/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         31         39      0.785      0.783      0.811      0.495
#                    Car         31         19        0.7      0.616      0.669      0.428
#             Motorcycle         31         20       0.87       0.95      0.953      0.562
# Speed: 2.0ms preprocess, 20.6ms inference, 0.0ms loss, 20.1ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model="/kaggle/working/runs/detect/train/weights/best.pt" conf = 0.65 source = "/kaggle/input/car-and-motorcycle/car and motorcycle.v1i.yolov8/test/images"
# Out:
# Ultralytics YOLOv8.1.20 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/16 /kaggle/input/car-and-motorcycle/car and motorcycle.v1i.yolov8/test/images/9815ca21-7d54-4890-9841-27464598ee7d_jpg.rf.e8491526f64e3e13562d441f41f7decb.jpg: 416x640 1 Car, 93.6ms
# image 2/16 /kaggle/input/car-and-motorcycle/car and motorcycle.v1i.yolov8/test/images/9dec0a25-5f24-481a-92b7-acf6c94ee648_jpg.rf.450b109f3ad667155edbb28e6b0593f1.jpg: 416x640 (no detections), 6.9ms
# image 3/16 /kaggle/input/car-and-motorcycle/car and motorcycle.v1i.yolov8/test/images/a4c1fd52-603a-4d2e-8669-f5479ec750fe_jpg.rf.904eee5bc2ce42720801e03828be9e38.jpg: 416x640 1 Motorcycle, 7.0ms
# image 4/16 /kaggle/input/car-and-motorcycle/car and motorcycle.v1i.yolov8/test/images/a7737573-25c3-43ac-a48d-692a37a0799a_jpg.rf.968408bc2f9d9fd92a26287d3778af15.jpg: 384x640 10 Cars, 60.2ms
# ...

# %%
import matplotlib.pyplot as plt

# %%
img_path = '/kaggle/working/runs/detect/predict/d405f76d-781d-4bf1-83cd-147d3f48a7e3_jpg.rf.2d27c13d78bdd1dd520bddfc8917cde1.jpg'
img = plt.imread(img_path)

plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis(False)
plt.show()
